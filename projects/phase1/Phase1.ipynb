# %% [markdown]
# # **Artificial Intelligence**

# %% [markdown]
# # Phase1: Optimization & Gradient Descent on Pokemon dataset

# %% [markdown]
# ## How to find parameters and predict the best line

# %% [markdown]
# #### Import Libraries

# %%
import numpy as np
import pandas as pd
from utils.plotting import *

np.random.seed(42)

# %% [markdown]
# #### Data Import

# %%
df = (pd.read_csv("data/pokemon.csv", usecols=['name', 'defense', 'attack'], index_col=0)
        .head(10)
        .sort_values(by='defense')
        .reset_index()
     )
x = df['defense']
y = df['attack']
df.head()

# %%
plot_pokemon(x, y)

# %% [markdown]
# ## Section 3: Finding parameters by Manually (15 points)

# %% [markdown]
# ### 3.1. Visually and Randomly

# %%
w0 = 0
w1 = #TODO: try with different values 
y_hat =  #TODO

# %%
plot_pokemon(x, y, y_hat)

# %% [markdown]
# ### 3.2. Grid Search

# %%
w0 = 0 
w1 = #TODO: try between [-5, 5] with 0.5 step
y_hat =  #TODO

# %%
def mean_squared_error(y, y_hat):
    # TODO

# %%
slopes = [] #TODO 
mse = pd.DataFrame({"slope": slopes,
                    "MSE": #TODO })
mse

# %%
plot_grid_search(x, y, slopes, mean_squared_error)

# %% [markdown]
# ## Section 4. Finding parameters by Gradient Descent algorithm

# %% [markdown]
# ### 4.1. Gradient Descent with One Parameter (30 points)

# %%
def gradient(x, y, w):
    # TODO

gradient(x, y, w=0.5)

# %%
def plot_gradient:
    # TODO

plot_gradient(x, y, 0.5, mse["slope"], mse["MSE"], gradient)

# %%
def gradient_descent(x, y, w, alpha, ϵ=2e-4, max_iterations=5000, print_progress=10):
    #TODO

gradient_descent(x, y, w=0.5, #TODO )

# %%
def plot_gradient_descent:
    # TODO

plot_gradient_descent(x, y, w, alpha)

# %% [markdown]
# ### 4.2. Effect of Learning Rate (15 points)

# %% [markdown]
# Run with different values for learning rate (α=[0.5,0.1,0.0001])

# %%
# TODO

# %% [markdown]
# ### 4.3. Gradient Descent with Two Parameter (25 points)

# %%
'''DON'T change the `slopes` and `intercepts` data range!'''
slopes = np.arange(0, 1.25, 0.25)
intercepts = np.arange(-20, 21, 1)

# %%
def plot_grid_search_2d(x, y, slopes, intercepts):
    # TODO

plot_grid_search_2d(x, y, slopes, intercepts)

# %%
def gradient(x, y, w):
    # TODO

gradient(x, y, w=[#TODO])

# %%
def gradient_descent(x, y, w, alpha, ϵ=2e-4, max_iterations=5000, print_progress=10):
    # TODO

gradient_descent(x, y, #TODO)

# %%
def plot_gradient_descent_2d:
    # TODO
    
plot_gradient_descent_2d(x, y, #TODO)

# %% [markdown]
# ### 4.4. Effect of Normalization (15 points)

# %%
x_new = # TODO

# %% [markdown]
# Now let's check a random gradient after scaling:

# %%
gradient(x_new, y, w)

# %% [markdown]
# Great, our gradients are on a similar scale now, let's retry gradient descent with our scaled data:

# %%
gradient_descent(x_new, y, w, alpha)

# %%
def plot_gradient_descent_2d():
    #TODO
